# %%
import os
workdir = os.environ.get('TRAJECTORY_WORKDIR', '/workspace')
project = os.environ.get('PROJECT_TAG', '')
print(workdir, project)
# list files
for f in os.listdir(workdir):
    print(f)
# Out:
# /workspace/62239727-4901-4551-a59a-3c6256aed82b
# .prompts
# .kernel_llm_logs_1.txt
# 17-suggested-reviewers.md
# si.pdf
# 16-journal-editors.md
# memory
# .config
# main.pdf

# %%
# Quick sanity check on word counts and section labels to anchor specific citations.
# Just structural — I have what I need. Now compose the review panel.
print("ok")
# Out:
# ok

# %%
# I will now write the mock review panel as a markdown deliverable.
# Personas chosen (one per category, all from 17-suggested-reviewers.md):
#  - SDL/automation: Milad Abolhasani (NC State)
#  - Powder dosing metrology: Johannes Khinast (TU Graz / RCPE)
#  - LLM/generative CAD: Adriana Schulz (U. Washington)
#
# Handling editor: Alán Aspuru-Guzik per note 16.

import os, pathlib
out_dir = pathlib.Path(os.environ['TRAJECTORY_WORKDIR'])
print(out_dir)
# Out:
# /workspace/62239727-4901-4551-a59a-3c6256aed82b
