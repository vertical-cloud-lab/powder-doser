# %%
import os
workdir = os.environ.get('TRAJECTORY_WORKDIR')
project_tag = os.environ.get('PROJECT_TAG')
print(workdir, project_tag)
# Out:
# /workspace/7036c0b2-f438-4720-ae3f-4a972578d0b1 None

# %%
workdir = "/workspace/7036c0b2-f438-4720-ae3f-4a972578d0b1"
import os
os.listdir(workdir)
# Out:
# ['memory',
#  '.prompts',
#  'main.pdf',
#  'si.pdf',
#  '17-suggested-reviewers.md',
#  '.kernel_llm_logs_1.txt',
#  '16-journal-editors.md',
#  '.config']

# %%
os.environ['PROJECT_TAG'] = '7036c0b2-f438-4720-ae3f-4a972578d0b1'

# %%
print("ready to compose review")
# Out:
# ready to compose review
